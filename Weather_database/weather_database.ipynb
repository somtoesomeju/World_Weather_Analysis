# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-75.000, high=75.000, size=2000)
lngs = np.random.uniform(low=-160.000, high=160.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Identify latitude and longitude combination the nearest cities.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If city is not present ad to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count 
len(cities)
# Out:
# 909

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | vung tau
# Processing Record 3 of Set 1 | sabang
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | pimentel
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | horodnytsya
# Processing Record 11 of Set 1 | meulaboh
# Processing Record 12 of Set 1 | san cristobal
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | grand gaube
# Processing Record 15 of Set 1 | tsabong
# Processing Record 16 of Set 1 | ust-nera
# Processing Record 17 of Set 1 | seoul
# Processing Record 18 of Set 1 | aksu
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | alice springs
# Processing Record 21 of Set 1 | gambela
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | araouane
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | kovur
# Processing Record 27 of Set 1 | sheltozero
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | ikongo
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | riyadh
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 1 | jiuquan
# Processing Record 36 of Set 1 | shenkursk
# Processing Record 37 of Set 1 | himora
# City not found. Skipping...
# Processing Record 38 of Set 1 | hirara
# Processing Record 39 of Set 1 | namibe
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | harrison
# Processing Record 42 of Set 1 | zhigansk
# Processing Record 43 of Set 1 | vernon
# Processing Record 44 of Set 1 | nuuk
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | aklavik
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | huai thalaeng
# Processing Record 49 of Set 1 | kirya
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | yenagoa
# Processing Record 2 of Set 2 | poronaysk
# Processing Record 3 of Set 2 | soubre
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | kargil
# Processing Record 8 of Set 2 | sungaipenuh
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | ulladulla
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | shebunino
# Processing Record 13 of Set 2 | impfondo
# Processing Record 14 of Set 2 | shaoxing
# Processing Record 15 of Set 2 | puruliya
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | ixtapa
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | road town
# Processing Record 22 of Set 2 | zheleznodorozhnyy
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | yarmouth
# Processing Record 25 of Set 2 | santa maria
# Processing Record 26 of Set 2 | mahibadhoo
# Processing Record 27 of Set 2 | maumere
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | covington
# Processing Record 30 of Set 2 | vostok
# Processing Record 31 of Set 2 | iralaya
# Processing Record 32 of Set 2 | houma
# Processing Record 33 of Set 2 | rognan
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | fort myers beach
# Processing Record 36 of Set 2 | senanga
# Processing Record 37 of Set 2 | atuntaqui
# Processing Record 38 of Set 2 | kahului
# Processing Record 39 of Set 2 | high level
# Processing Record 40 of Set 2 | palma
# Processing Record 41 of Set 2 | manado
# Processing Record 42 of Set 2 | pangody
# Processing Record 43 of Set 2 | hofn
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | warmbad
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | artigas
# Processing Record 49 of Set 2 | burnie
# Processing Record 50 of Set 2 | zhuozhou
# City not found. Skipping...
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | winnemucca
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | batagay-alyta
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | port blair
# Processing Record 10 of Set 3 | agva
# City not found. Skipping...
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | pangnirtung
# Processing Record 13 of Set 3 | chumikan
# Processing Record 14 of Set 3 | amparafaravola
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | kutum
# Processing Record 17 of Set 3 | mao
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | skjervoy
# Processing Record 20 of Set 3 | pyapon
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | dwarka
# Processing Record 23 of Set 3 | luocheng
# Processing Record 24 of Set 3 | galle
# Processing Record 25 of Set 3 | kudahuvadhoo
# Processing Record 26 of Set 3 | zhezkazgan
# Processing Record 27 of Set 3 | djibo
# Processing Record 28 of Set 3 | roma
# Processing Record 29 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 3 | zhuhai
# Processing Record 31 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | sandorfalva
# Processing Record 34 of Set 3 | sumbe
# Processing Record 35 of Set 3 | san jose de guanipa
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | nouadhibou
# Processing Record 38 of Set 3 | waw
# Processing Record 39 of Set 3 | zharkent
# Processing Record 40 of Set 3 | puerto madryn
# Processing Record 41 of Set 3 | half moon bay
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | north bend
# Processing Record 44 of Set 3 | inhambane
# Processing Record 45 of Set 3 | turukhansk
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | dayong
# Processing Record 49 of Set 3 | mikkeli
# Processing Record 50 of Set 3 | lorengau
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | chengde
# Processing Record 3 of Set 4 | wanning
# Processing Record 4 of Set 4 | asfi
# Processing Record 5 of Set 4 | constitucion
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | tura
# Processing Record 8 of Set 4 | aranda de duero
# Processing Record 9 of Set 4 | kropotkin
# Processing Record 10 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 4 | elban
# Processing Record 12 of Set 4 | boguchany
# Processing Record 13 of Set 4 | ibra
# Processing Record 14 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 4 | cockburn town
# Processing Record 16 of Set 4 | vetapalem
# Processing Record 17 of Set 4 | maltahohe
# Processing Record 18 of Set 4 | faya
# Processing Record 19 of Set 4 | cayenne
# Processing Record 20 of Set 4 | wadi musa
# Processing Record 21 of Set 4 | snezhnogorsk
# Processing Record 22 of Set 4 | korla
# Processing Record 23 of Set 4 | blackwater
# Processing Record 24 of Set 4 | padang
# Processing Record 25 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 4 | manokwari
# Processing Record 27 of Set 4 | warrnambool
# Processing Record 28 of Set 4 | yanam
# Processing Record 29 of Set 4 | adrar
# Processing Record 30 of Set 4 | tuatapere
# Processing Record 31 of Set 4 | ndago
# Processing Record 32 of Set 4 | portland
# Processing Record 33 of Set 4 | hatillo
# Processing Record 34 of Set 4 | hobart
# Processing Record 35 of Set 4 | puerto leguizamo
# Processing Record 36 of Set 4 | havoysund
# Processing Record 37 of Set 4 | torbay
# Processing Record 38 of Set 4 | proletarsk
# Processing Record 39 of Set 4 | nola
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | dicabisagan
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | tezu
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | inuvik
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 4 | henties bay
# Processing Record 49 of Set 4 | paso de los toros
# Processing Record 50 of Set 4 | porto novo
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | hay river
# Processing Record 3 of Set 5 | kloulklubed
# Processing Record 4 of Set 5 | delta del tigre
# Processing Record 5 of Set 5 | kromy
# Processing Record 6 of Set 5 | isetskoye
# Processing Record 7 of Set 5 | ulaangom
# Processing Record 8 of Set 5 | opuwo
# Processing Record 9 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 10 of Set 5 | mamakan
# Processing Record 11 of Set 5 | sao lourenco
# Processing Record 12 of Set 5 | izumo
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | vredendal
# Processing Record 16 of Set 5 | carepa
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | muyezerskiy
# Processing Record 20 of Set 5 | selikhino
# Processing Record 21 of Set 5 | soyo
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | les cayes
# Processing Record 24 of Set 5 | omsk
# Processing Record 25 of Set 5 | jiaojiang
# Processing Record 26 of Set 5 | lixourion
# Processing Record 27 of Set 5 | auray
# Processing Record 28 of Set 5 | khani
# Processing Record 29 of Set 5 | poros
# Processing Record 30 of Set 5 | momcilgrad
# City not found. Skipping...
# Processing Record 31 of Set 5 | san quintin
# Processing Record 32 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 5 | ca mau
# Processing Record 34 of Set 5 | kismayo
# Processing Record 35 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 5 | yaan
# Processing Record 37 of Set 5 | ahar
# Processing Record 38 of Set 5 | bongandanga
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | tecpan
# Processing Record 41 of Set 5 | smithers
# Processing Record 42 of Set 5 | mindelo
# Processing Record 43 of Set 5 | kota belud
# Processing Record 44 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 5 | buchanan
# Processing Record 46 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 5 | villa carlos paz
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | san jose
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | kagadi
# Processing Record 3 of Set 6 | batemans bay
# Processing Record 4 of Set 6 | broome
# Processing Record 5 of Set 6 | sur
# Processing Record 6 of Set 6 | jaque
# Processing Record 7 of Set 6 | xining
# Processing Record 8 of Set 6 | beisfjord
# Processing Record 9 of Set 6 | ocos
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | jiayuguan
# Processing Record 12 of Set 6 | shingu
# Processing Record 13 of Set 6 | sedro-woolley
# Processing Record 14 of Set 6 | correntina
# Processing Record 15 of Set 6 | zyryanka
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | kamina
# Processing Record 18 of Set 6 | northam
# Processing Record 19 of Set 6 | thinadhoo
# Processing Record 20 of Set 6 | bilma
# Processing Record 21 of Set 6 | cherdyn
# Processing Record 22 of Set 6 | san jeronimito
# Processing Record 23 of Set 6 | ekibastuz
# Processing Record 24 of Set 6 | rivne
# Processing Record 25 of Set 6 | batagay
# Processing Record 26 of Set 6 | flinders
# Processing Record 27 of Set 6 | marzuq
# Processing Record 28 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 6 | tuktoyaktuk
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | olga
# Processing Record 32 of Set 6 | poum
# Processing Record 33 of Set 6 | gat
# Processing Record 34 of Set 6 | lubango
# Processing Record 35 of Set 6 | souillac
# Processing Record 36 of Set 6 | komatipoort
# Processing Record 37 of Set 6 | sitka
# Processing Record 38 of Set 6 | cassilandia
# Processing Record 39 of Set 6 | toamasina
# Processing Record 40 of Set 6 | kattivakkam
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | naron
# Processing Record 43 of Set 6 | anloga
# Processing Record 44 of Set 6 | bridgetown
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | avera
# Processing Record 47 of Set 6 | santa fe
# Processing Record 48 of Set 6 | broken hill
# Processing Record 49 of Set 6 | manta
# Processing Record 50 of Set 6 | ondjiva
# Processing Record 1 of Set 7 | pervomayskoye
# Processing Record 2 of Set 7 | fare
# Processing Record 3 of Set 7 | bantry
# Processing Record 4 of Set 7 | moroni
# Processing Record 5 of Set 7 | cavalcante
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | okhotsk
# Processing Record 8 of Set 7 | tamandare
# Processing Record 9 of Set 7 | kununurra
# Processing Record 10 of Set 7 | bauchi
# Processing Record 11 of Set 7 | abu kamal
# Processing Record 12 of Set 7 | ratnagiri
# Processing Record 13 of Set 7 | havre-saint-pierre
# Processing Record 14 of Set 7 | altagracia de orituco
# Processing Record 15 of Set 7 | presidencia roque saenz pena
# Processing Record 16 of Set 7 | diego de almagro
# Processing Record 17 of Set 7 | college
# Processing Record 18 of Set 7 | solwezi
# Processing Record 19 of Set 7 | bolu
# Processing Record 20 of Set 7 | mecca
# Processing Record 21 of Set 7 | asyut
# Processing Record 22 of Set 7 | luanda
# Processing Record 23 of Set 7 | aldan
# Processing Record 24 of Set 7 | ambilobe
# Processing Record 25 of Set 7 | srednekolymsk
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | hargeysa
# Processing Record 28 of Set 7 | yumbe
# Processing Record 29 of Set 7 | sisimiut
# Processing Record 30 of Set 7 | murmino
# Processing Record 31 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | rezekne
# Processing Record 34 of Set 7 | jabinyanah
# Processing Record 35 of Set 7 | dolores
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | fuyu
# Processing Record 38 of Set 7 | dongsheng
# Processing Record 39 of Set 7 | andros town
# Processing Record 40 of Set 7 | saint-georges
# Processing Record 41 of Set 7 | idar
# Processing Record 42 of Set 7 | kaseda
# Processing Record 43 of Set 7 | bac lieu
# Processing Record 44 of Set 7 | rosetown
# Processing Record 45 of Set 7 | waingapu
# Processing Record 46 of Set 7 | paragominas
# Processing Record 47 of Set 7 | bequimao
# Processing Record 48 of Set 7 | yangambi
# Processing Record 49 of Set 7 | saint-philippe
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | omboue
# Processing Record 2 of Set 8 | lhokseumawe
# Processing Record 3 of Set 8 | prince albert
# Processing Record 4 of Set 8 | omsukchan
# Processing Record 5 of Set 8 | ballina
# Processing Record 6 of Set 8 | ouesso
# Processing Record 7 of Set 8 | acari
# Processing Record 8 of Set 8 | yumen
# Processing Record 9 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 8 | ferme-neuve
# Processing Record 11 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 8 | smirnykh
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | pathein
# Processing Record 15 of Set 8 | tarakan
# Processing Record 16 of Set 8 | hansot
# Processing Record 17 of Set 8 | acapulco
# Processing Record 18 of Set 8 | kenai
# Processing Record 19 of Set 8 | rubtsovsk
# Processing Record 20 of Set 8 | myitkyina
# Processing Record 21 of Set 8 | zabaykalsk
# Processing Record 22 of Set 8 | saldanha
# Processing Record 23 of Set 8 | linapacan
# City not found. Skipping...
# Processing Record 24 of Set 8 | nicoya
# Processing Record 25 of Set 8 | newark
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | radford
# Processing Record 28 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 8 | carauari
# Processing Record 30 of Set 8 | port elizabeth
# Processing Record 31 of Set 8 | abu dhabi
# Processing Record 32 of Set 8 | tshikapa
# Processing Record 33 of Set 8 | izsak
# Processing Record 34 of Set 8 | muravlenko
# Processing Record 35 of Set 8 | drayton valley
# Processing Record 36 of Set 8 | kapaa
# Processing Record 37 of Set 8 | ahuimanu
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | north mankato
# Processing Record 40 of Set 8 | the valley
# Processing Record 41 of Set 8 | rengo
# Processing Record 42 of Set 8 | avanigadda
# Processing Record 43 of Set 8 | igarka
# Processing Record 44 of Set 8 | ponta do sol
# Processing Record 45 of Set 8 | burley
# Processing Record 46 of Set 8 | vila velha
# Processing Record 47 of Set 8 | remontnoye
# Processing Record 48 of Set 8 | samarai
# Processing Record 49 of Set 8 | birao
# Processing Record 50 of Set 8 | kota kinabalu
# Processing Record 1 of Set 9 | norwich
# Processing Record 2 of Set 9 | okha
# Processing Record 3 of Set 9 | stornoway
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | magadan
# Processing Record 7 of Set 9 | tarpon springs
# Processing Record 8 of Set 9 | calama
# Processing Record 9 of Set 9 | bulungu
# Processing Record 10 of Set 9 | eureka
# Processing Record 11 of Set 9 | las vegas
# Processing Record 12 of Set 9 | wamba
# Processing Record 13 of Set 9 | kindu
# Processing Record 14 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 15 of Set 9 | kabare
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | kulunda
# Processing Record 18 of Set 9 | ravar
# Processing Record 19 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 9 | guerrero negro
# Processing Record 21 of Set 9 | puerto carreno
# Processing Record 22 of Set 9 | saskylakh
# Processing Record 23 of Set 9 | antofagasta
# Processing Record 24 of Set 9 | gbarnga
# Processing Record 25 of Set 9 | buin
# Processing Record 26 of Set 9 | kapuvar
# Processing Record 27 of Set 9 | leshukonskoye
# Processing Record 28 of Set 9 | khargapur
# Processing Record 29 of Set 9 | chapais
# Processing Record 30 of Set 9 | fort frances
# Processing Record 31 of Set 9 | luderitz
# Processing Record 32 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 9 | izvestkovyy
# Processing Record 34 of Set 9 | moba
# Processing Record 35 of Set 9 | quatre cocos
# Processing Record 36 of Set 9 | altay
# Processing Record 37 of Set 9 | boma
# Processing Record 38 of Set 9 | rio tercero
# Processing Record 39 of Set 9 | bonavista
# Processing Record 40 of Set 9 | san angelo
# Processing Record 41 of Set 9 | itoman
# Processing Record 42 of Set 9 | mor
# Processing Record 43 of Set 9 | suslovo
# Processing Record 44 of Set 9 | eyl
# Processing Record 45 of Set 9 | rio pomba
# Processing Record 46 of Set 9 | sakakah
# Processing Record 47 of Set 9 | tomatlan
# Processing Record 48 of Set 9 | orotukan
# Processing Record 49 of Set 9 | edd
# Processing Record 50 of Set 9 | oussouye
# Processing Record 1 of Set 10 | bichura
# Processing Record 2 of Set 10 | dukat
# Processing Record 3 of Set 10 | hamilton
# Processing Record 4 of Set 10 | la ronge
# Processing Record 5 of Set 10 | rorvik
# Processing Record 6 of Set 10 | luan
# Processing Record 7 of Set 10 | goregaon
# Processing Record 8 of Set 10 | qaanaaq
# Processing Record 9 of Set 10 | margate
# Processing Record 10 of Set 10 | sesheke
# Processing Record 11 of Set 10 | vigrestad
# Processing Record 12 of Set 10 | ndele
# Processing Record 13 of Set 10 | rosarito
# Processing Record 14 of Set 10 | pafos
# Processing Record 15 of Set 10 | mackay
# Processing Record 16 of Set 10 | machico
# Processing Record 17 of Set 10 | surt
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | polovinnoye
# Processing Record 20 of Set 10 | orlik
# Processing Record 21 of Set 10 | cherskiy
# Processing Record 22 of Set 10 | ewa beach
# Processing Record 23 of Set 10 | port-cartier
# Processing Record 24 of Set 10 | aloleng
# Processing Record 25 of Set 10 | vancouver
# Processing Record 26 of Set 10 | lahaina
# Processing Record 27 of Set 10 | sarh
# Processing Record 28 of Set 10 | nioro
# Processing Record 29 of Set 10 | gamba
# Processing Record 30 of Set 10 | abatskoye
# Processing Record 31 of Set 10 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 32 of Set 10 | severobaykalsk
# Processing Record 33 of Set 10 | bukama
# Processing Record 34 of Set 10 | san vicente
# Processing Record 35 of Set 10 | khandagayty
# Processing Record 36 of Set 10 | aswan
# Processing Record 37 of Set 10 | silver city
# Processing Record 38 of Set 10 | mabaruma
# Processing Record 39 of Set 10 | miles city
# Processing Record 40 of Set 10 | zlobin
# Processing Record 41 of Set 10 | mumford
# Processing Record 42 of Set 10 | amga
# Processing Record 43 of Set 10 | channel-port aux basques
# Processing Record 44 of Set 10 | mattru
# Processing Record 45 of Set 10 | geraldton
# Processing Record 46 of Set 10 | agadir
# Processing Record 47 of Set 10 | vietri sul mare
# Processing Record 48 of Set 10 | timbiqui
# Processing Record 49 of Set 10 | zanjan
# Processing Record 50 of Set 10 | aix-les-bains
# Processing Record 1 of Set 11 | palmer
# Processing Record 2 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 11 | jalu
# Processing Record 4 of Set 11 | muroto
# Processing Record 5 of Set 11 | kamenka
# Processing Record 6 of Set 11 | baghmara
# Processing Record 7 of Set 11 | ranong
# Processing Record 8 of Set 11 | saint-joseph
# Processing Record 9 of Set 11 | talnakh
# Processing Record 10 of Set 11 | wattegama
# Processing Record 11 of Set 11 | bowen
# Processing Record 12 of Set 11 | sakaiminato
# Processing Record 13 of Set 11 | lima duarte
# Processing Record 14 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 15 of Set 11 | fez
# Processing Record 16 of Set 11 | teya
# Processing Record 17 of Set 11 | luau
# Processing Record 18 of Set 11 | karratha
# Processing Record 19 of Set 11 | lompoc
# Processing Record 20 of Set 11 | nadbai
# Processing Record 21 of Set 11 | tsaratanana
# Processing Record 22 of Set 11 | kiama
# Processing Record 23 of Set 11 | rawson
# Processing Record 24 of Set 11 | sambava
# Processing Record 25 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 11 | onega
# Processing Record 27 of Set 11 | bethel
# Processing Record 28 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | fraserburgh
# Processing Record 30 of Set 11 | bubaque
# Processing Record 31 of Set 11 | berdigestyakh
# Processing Record 32 of Set 11 | novoorsk
# Processing Record 33 of Set 11 | jedrzejow
# Processing Record 34 of Set 11 | kawalu
# Processing Record 35 of Set 11 | shelburne
# Processing Record 36 of Set 11 | mount isa
# Processing Record 37 of Set 11 | saint-augustin
# Processing Record 38 of Set 11 | pengcheng
# Processing Record 39 of Set 11 | sao joao da barra
# Processing Record 40 of Set 11 | sarti
# Processing Record 41 of Set 11 | chicama
# Processing Record 42 of Set 11 | kizukuri
# Processing Record 43 of Set 11 | sosnovoborsk
# Processing Record 44 of Set 11 | saint anthony
# Processing Record 45 of Set 11 | tongliao
# Processing Record 46 of Set 11 | remiremont
# Processing Record 47 of Set 11 | mashhad
# Processing Record 48 of Set 11 | dutlwe
# Processing Record 49 of Set 11 | culfa
# Processing Record 50 of Set 11 | qasigiannguit
# Processing Record 1 of Set 12 | macheng
# Processing Record 2 of Set 12 | maymanak
# City not found. Skipping...
# Processing Record 3 of Set 12 | richards bay
# Processing Record 4 of Set 12 | nichinan
# Processing Record 5 of Set 12 | sevierville
# Processing Record 6 of Set 12 | belmonte
# Processing Record 7 of Set 12 | joura
# Processing Record 8 of Set 12 | krasnoselkup
# Processing Record 9 of Set 12 | ugento
# Processing Record 10 of Set 12 | shimanovsk
# Processing Record 11 of Set 12 | acara
# Processing Record 12 of Set 12 | yuma
# Processing Record 13 of Set 12 | dehra dun
# Processing Record 14 of Set 12 | millbrook
# Processing Record 15 of Set 12 | shushenskoye
# Processing Record 16 of Set 12 | qiyang
# Processing Record 17 of Set 12 | nizwa
# Processing Record 18 of Set 12 | campobasso
# Processing Record 19 of Set 12 | payyannur
# Processing Record 20 of Set 12 | whitley bay
# Processing Record 21 of Set 12 | avarua
# Processing Record 22 of Set 12 | takahashi
# Processing Record 23 of Set 12 | biak
# Processing Record 24 of Set 12 | hohhot
# Processing Record 25 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 12 | daman
# Processing Record 27 of Set 12 | chardara
# Processing Record 28 of Set 12 | rio grande
# Processing Record 29 of Set 12 | xai-xai
# Processing Record 30 of Set 12 | nhulunbuy
# Processing Record 31 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 12 | san jeronimo
# Processing Record 33 of Set 12 | los llanos de aridane
# Processing Record 34 of Set 12 | tabou
# Processing Record 35 of Set 12 | urumqi
# Processing Record 36 of Set 12 | talbahat
# Processing Record 37 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 12 | sao filipe
# Processing Record 39 of Set 12 | hambantota
# Processing Record 40 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 12 | clonakilty
# Processing Record 42 of Set 12 | san patricio
# Processing Record 43 of Set 12 | florida
# Processing Record 44 of Set 12 | mahajanga
# Processing Record 45 of Set 12 | alta floresta
# Processing Record 46 of Set 12 | ekhabi
# Processing Record 47 of Set 12 | yulara
# Processing Record 48 of Set 12 | hushitai
# Processing Record 49 of Set 12 | morondava
# Processing Record 50 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 1 of Set 13 | saint-louis
# Processing Record 2 of Set 13 | upington
# Processing Record 3 of Set 13 | santa rosa
# Processing Record 4 of Set 13 | klaksvik
# Processing Record 5 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 6 of Set 13 | mertoyudan
# Processing Record 7 of Set 13 | georgetown
# Processing Record 8 of Set 13 | rundu
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | saint-francois
# Processing Record 11 of Set 13 | shahrud
# Processing Record 12 of Set 13 | esmeralda
# Processing Record 13 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 13 | mujiayingzi
# Processing Record 15 of Set 13 | mayumba
# Processing Record 16 of Set 13 | basoko
# Processing Record 17 of Set 13 | vanimo
# Processing Record 18 of Set 13 | pervouralsk
# Processing Record 19 of Set 13 | parrita
# Processing Record 20 of Set 13 | nipawin
# Processing Record 21 of Set 13 | okakarara
# Processing Record 22 of Set 13 | dzilam gonzalez
# Processing Record 23 of Set 13 | guarapari
# Processing Record 24 of Set 13 | evensk
# Processing Record 25 of Set 13 | kaihua
# Processing Record 26 of Set 13 | tupik
# Processing Record 27 of Set 13 | sann
# Processing Record 28 of Set 13 | magnolia
# Processing Record 29 of Set 13 | kungurtug
# Processing Record 30 of Set 13 | sibolga
# Processing Record 31 of Set 13 | ranikhet
# Processing Record 32 of Set 13 | manor
# Processing Record 33 of Set 13 | falmouth
# Processing Record 34 of Set 13 | pontal do parana
# Processing Record 35 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 13 | puerto ayacucho
# Processing Record 37 of Set 13 | paamiut
# Processing Record 38 of Set 13 | maragheh
# Processing Record 39 of Set 13 | najran
# Processing Record 40 of Set 13 | moog
# Processing Record 41 of Set 13 | saint-pierre
# Processing Record 42 of Set 13 | aleksandrov gay
# Processing Record 43 of Set 13 | great yarmouth
# Processing Record 44 of Set 13 | grand island
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | bonthe
# Processing Record 47 of Set 13 | wittenberge
# Processing Record 48 of Set 13 | mezhdurechensk
# Processing Record 49 of Set 13 | hualmay
# Processing Record 50 of Set 13 | along
# Processing Record 1 of Set 14 | syasstroy
# Processing Record 2 of Set 14 | banikoara
# Processing Record 3 of Set 14 | rosario
# Processing Record 4 of Set 14 | brasilia
# Processing Record 5 of Set 14 | goiania
# Processing Record 6 of Set 14 | mocajuba
# Processing Record 7 of Set 14 | cabra
# Processing Record 8 of Set 14 | kankon
# Processing Record 9 of Set 14 | santa cruz
# Processing Record 10 of Set 14 | waddan
# Processing Record 11 of Set 14 | talaya
# Processing Record 12 of Set 14 | vilyuysk
# Processing Record 13 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 14 | balkanabat
# Processing Record 15 of Set 14 | kavaratti
# Processing Record 16 of Set 14 | jasper
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | goderich
# Processing Record 19 of Set 14 | alyangula
# Processing Record 20 of Set 14 | boa vista
# Processing Record 21 of Set 14 | bristol
# Processing Record 22 of Set 14 | aksarka
# Processing Record 23 of Set 14 | dikson
# Processing Record 24 of Set 14 | boffa
# Processing Record 25 of Set 14 | rudbar
# Processing Record 26 of Set 14 | shu
# Processing Record 27 of Set 14 | pierre
# Processing Record 28 of Set 14 | mitu
# Processing Record 29 of Set 14 | bandarbeyla
# Processing Record 30 of Set 14 | babati
# Processing Record 31 of Set 14 | katsuura
# Processing Record 32 of Set 14 | tonekabon
# Processing Record 33 of Set 14 | susah
# City not found. Skipping...
# Processing Record 34 of Set 14 | tete
# Processing Record 35 of Set 14 | emerald
# Processing Record 36 of Set 14 | murud
# Processing Record 37 of Set 14 | ola
# Processing Record 38 of Set 14 | casper
# Processing Record 39 of Set 14 | chipinge
# Processing Record 40 of Set 14 | barinas
# Processing Record 41 of Set 14 | chernyanka
# Processing Record 42 of Set 14 | alekseyevka
# Processing Record 43 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 14 | matozinhos
# Processing Record 45 of Set 14 | peikang
# City not found. Skipping...
# Processing Record 46 of Set 14 | umba
# Processing Record 47 of Set 14 | rostovka
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | aripuana
# Processing Record 50 of Set 14 | ilulissat
# Processing Record 1 of Set 15 | sal rei
# Processing Record 2 of Set 15 | mocuba
# Processing Record 3 of Set 15 | marsa matruh
# Processing Record 4 of Set 15 | fort smith
# Processing Record 5 of Set 15 | andradina
# Processing Record 6 of Set 15 | portobelo
# Processing Record 7 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 15 | saryozek
# Processing Record 9 of Set 15 | kodinar
# Processing Record 10 of Set 15 | sumter
# Processing Record 11 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 15 | gumushane
# City not found. Skipping...
# Processing Record 13 of Set 15 | colina
# Processing Record 14 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 15 | sioux lookout
# Processing Record 16 of Set 15 | huarmey
# Processing Record 17 of Set 15 | seaham
# Processing Record 18 of Set 15 | hovd
# Processing Record 19 of Set 15 | jaciara
# Processing Record 20 of Set 15 | kabo
# Processing Record 21 of Set 15 | stokmarknes
# Processing Record 22 of Set 15 | winneba
# Processing Record 23 of Set 15 | ocean city
# Processing Record 24 of Set 15 | chateaubelair
# Processing Record 25 of Set 15 | sadasivpet
# Processing Record 26 of Set 15 | huambo
# Processing Record 27 of Set 15 | naestved
# Processing Record 28 of Set 15 | katherine
# Processing Record 29 of Set 15 | andenes
# Processing Record 30 of Set 15 | sault sainte marie
# Processing Record 31 of Set 15 | freetown
# Processing Record 32 of Set 15 | venado tuerto
# Processing Record 33 of Set 15 | green river
# Processing Record 34 of Set 15 | ordu
# Processing Record 35 of Set 15 | vasto
# Processing Record 36 of Set 15 | altamira
# Processing Record 37 of Set 15 | chlorakas
# Processing Record 38 of Set 15 | doka
# Processing Record 39 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 15 | young
# Processing Record 41 of Set 15 | qandala
# Processing Record 42 of Set 15 | albion
# Processing Record 43 of Set 15 | cabedelo
# Processing Record 44 of Set 15 | tocopilla
# Processing Record 45 of Set 15 | homer
# Processing Record 46 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 15 | doha
# Processing Record 48 of Set 15 | daudnagar
# Processing Record 49 of Set 15 | shar
# Processing Record 50 of Set 15 | kozhevnikovo
# Processing Record 1 of Set 16 | baykit
# Processing Record 2 of Set 16 | salem
# Processing Record 3 of Set 16 | nchelenge
# Processing Record 4 of Set 16 | lapua
# Processing Record 5 of Set 16 | holme
# Processing Record 6 of Set 16 | gilgil
# City not found. Skipping...
# Processing Record 7 of Set 16 | dingzhou
# Processing Record 8 of Set 16 | andilamena
# Processing Record 9 of Set 16 | balkhash
# Processing Record 10 of Set 16 | old town
# Processing Record 11 of Set 16 | ngawen
# Processing Record 12 of Set 16 | maharajganj
# Processing Record 13 of Set 16 | big spring
# Processing Record 14 of Set 16 | bosaso
# Processing Record 15 of Set 16 | ipixuna
# Processing Record 16 of Set 16 | bagaces
# Processing Record 17 of Set 16 | kabompo
# Processing Record 18 of Set 16 | osa
# Processing Record 19 of Set 16 | ust-tarka
# Processing Record 20 of Set 16 | heihe
# Processing Record 21 of Set 16 | tonantins
# Processing Record 22 of Set 16 | goure
# Processing Record 23 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 16 | landang
# City not found. Skipping...
# Processing Record 25 of Set 16 | roebourne
# Processing Record 26 of Set 16 | drummondville
# Processing Record 27 of Set 16 | lerwick
# Processing Record 28 of Set 16 | kaduy
# Processing Record 29 of Set 16 | pozoblanco
# Processing Record 30 of Set 16 | van buren
# Processing Record 31 of Set 16 | lukovetskiy
# Processing Record 32 of Set 16 | eldikan
# City not found. Skipping...
# Processing Record 33 of Set 16 | kulhudhuffushi
# Processing Record 34 of Set 16 | summerville
# Processing Record 35 of Set 16 | mogok
# Processing Record 36 of Set 16 | gibara
# Processing Record 37 of Set 16 | hobyo
# Processing Record 38 of Set 16 | akureyri
# Processing Record 39 of Set 16 | san andres
# Processing Record 40 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 41 of Set 16 | murmashi
# Processing Record 42 of Set 16 | pemangkat
# Processing Record 43 of Set 16 | raudeberg
# Processing Record 44 of Set 16 | chara
# Processing Record 45 of Set 16 | kupang
# Processing Record 46 of Set 16 | fiumicino
# Processing Record 47 of Set 16 | ustka
# Processing Record 48 of Set 16 | lavumisa
# Processing Record 49 of Set 16 | hailar
# Processing Record 50 of Set 16 | kangaatsiaq
# Processing Record 1 of Set 17 | casa nova
# Processing Record 2 of Set 17 | zhangjiakou
# Processing Record 3 of Set 17 | verkhoyansk
# Processing Record 4 of Set 17 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 17 | taguatinga
# Processing Record 6 of Set 17 | kuryk
# Processing Record 7 of Set 17 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 17 | kendari
# Processing Record 9 of Set 17 | otukpo
# Processing Record 10 of Set 17 | benguela
# Processing Record 11 of Set 17 | collie
# Processing Record 12 of Set 17 | pasto
# Processing Record 13 of Set 17 | north augusta
# Processing Record 14 of Set 17 | autazes
# Processing Record 15 of Set 17 | praia
# Processing Record 16 of Set 17 | sept-iles
# Processing Record 17 of Set 17 | gasa
# Processing Record 18 of Set 17 | nelson bay
# Processing Record 19 of Set 17 | la rioja
# Processing Record 20 of Set 17 | pacific grove
# Processing Record 21 of Set 17 | zarubino
# Processing Record 22 of Set 17 | zhigalovo
# Processing Record 23 of Set 17 | tripoli
# Processing Record 24 of Set 17 | monster
# Processing Record 25 of Set 17 | koygorodok
# Processing Record 26 of Set 17 | amapa
# Processing Record 27 of Set 17 | mercedes
# Processing Record 28 of Set 17 | itambacuri
# Processing Record 29 of Set 17 | del rio
# Processing Record 30 of Set 17 | baruun-urt
# Processing Record 31 of Set 17 | unye
# City not found. Skipping...
# Processing Record 32 of Set 17 | bahia de caraquez
# Processing Record 33 of Set 17 | montepuez
# Processing Record 34 of Set 17 | beaverlodge
# Processing Record 35 of Set 17 | pidhorodne
# Processing Record 36 of Set 17 | auburn
# Processing Record 37 of Set 17 | santa luzia
# Processing Record 38 of Set 17 | awjilah
# Processing Record 39 of Set 17 | puerto del rosario
# Processing Record 40 of Set 17 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 41 of Set 17 | shevchenkove
# Processing Record 42 of Set 17 | jacareacanga
# Processing Record 43 of Set 17 | grindavik
# Processing Record 44 of Set 17 | namatanai
# Processing Record 45 of Set 17 | shimoda
# Processing Record 46 of Set 17 | pochutla
# Processing Record 47 of Set 17 | port keats
# Processing Record 48 of Set 17 | rantepao
# Processing Record 49 of Set 17 | bonnyville
# Processing Record 50 of Set 17 | majene
# Processing Record 1 of Set 18 | arlit
# Processing Record 2 of Set 18 | makat
# Processing Record 3 of Set 18 | razole
# Processing Record 4 of Set 18 | harwich
# Processing Record 5 of Set 18 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 18 | lop buri
# Processing Record 7 of Set 18 | norman wells
# Processing Record 8 of Set 18 | sembabule
# Processing Record 9 of Set 18 | amalner
# Processing Record 10 of Set 18 | mayo
# Processing Record 11 of Set 18 | wenling
# Processing Record 12 of Set 18 | nogliki
# Processing Record 13 of Set 18 | deep river
# Processing Record 14 of Set 18 | yuksekova
# Processing Record 15 of Set 18 | zhashkiv
# Processing Record 16 of Set 18 | basco
# Processing Record 17 of Set 18 | rafai
# Processing Record 18 of Set 18 | balad
# Processing Record 19 of Set 18 | alcudia
# Processing Record 20 of Set 18 | abha
# Processing Record 21 of Set 18 | maun
# Processing Record 22 of Set 18 | labuhan
# Processing Record 23 of Set 18 | usinsk
# Processing Record 24 of Set 18 | rae bareli
# Processing Record 25 of Set 18 | dordrecht
# Processing Record 26 of Set 18 | redlands
# Processing Record 27 of Set 18 | carikar
# City not found. Skipping...
# Processing Record 28 of Set 18 | sayyan
# Processing Record 29 of Set 18 | trelew
# Processing Record 30 of Set 18 | taltal
# Processing Record 31 of Set 18 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 18 | paraopeba
# Processing Record 33 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 18 | bastia
# Processing Record 35 of Set 18 | barreiras
# Processing Record 36 of Set 18 | suntar
# Processing Record 37 of Set 18 | yurginskoye
# Processing Record 38 of Set 18 | guamuchil
# Processing Record 39 of Set 18 | khovu-aksy
# Processing Record 40 of Set 18 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 18 | sechura
# Processing Record 42 of Set 18 | kyshtovka
# Processing Record 43 of Set 18 | rocha
# Processing Record 44 of Set 18 | batticaloa
# Processing Record 45 of Set 18 | oktyabrskiy
# Processing Record 46 of Set 18 | kot putli
# City not found. Skipping...
# Processing Record 47 of Set 18 | sire
# Processing Record 48 of Set 18 | necochea
# Processing Record 49 of Set 18 | prince rupert
# Processing Record 50 of Set 18 | camacha
# Processing Record 1 of Set 19 | machinga
# Processing Record 2 of Set 19 | lodwar
# Processing Record 3 of Set 19 | shunyi
# Processing Record 4 of Set 19 | kerkini
# Processing Record 5 of Set 19 | thunder bay
# Processing Record 6 of Set 19 | lianran
# Processing Record 7 of Set 19 | mount gambier
# Processing Record 8 of Set 19 | bud
# Processing Record 9 of Set 19 | mazyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Vung Tau      VN  10.3460  107.0843     86.29        71          94
# 1       Sabang      ID   5.8933   95.3214     83.59        74          58
# 2  Port Alfred      ZA -33.5906   26.8910     55.17        83           0
# 3      Rikitea      PF -23.1203 -134.9692     74.53        76          10
# 4        Pisco      PE -13.7000  -76.2167     59.05        88          75
# 5         Lebu      CL -37.6167  -73.6500     49.53        88         100
# 6     Pimentel      PE  -6.8367  -79.9342     62.01        84          12
# 7    Bathsheba      BB  13.2167  -59.5167     79.41        83          40
# 8  Horodnytsya      UA  50.8070   27.3168     57.90        75          62
# 9     Meulaboh      ID   4.1363   96.1285     85.80        65          81
#
#    Wind Speed Current Description
# 0        8.75     overcast clouds
# 1       15.17       broken clouds
# 2        4.05           clear sky
# 3        7.92           clear sky
# 4        2.30       broken clouds
# 5        6.20     overcast clouds
# 6        3.00          few clouds
# 7       11.50    scattered clouds
# 8        9.31       broken clouds
# 9        5.50       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
